# %% [markdown]
# # Day 31 - Proximal Policy Optimization with Clipping (PPO-Clip): Theory and Implementation

# %% [markdown]
# ## Theory

# %% [markdown]
# ### Advantage Estimation and GAE

# %% [markdown]
# Generalized Advantage Estimation is a method that generalizes the two approaches
# of either collecting Monte Carlo returns, or computing TD errors to estimate the
# advantage:
# $$
# \hat{A}(s_t,a_t)=\delta_t+(\gamma\lambda)\delta_{t+1}+(\gamma\lambda)^2\delta_{t+2}+\dots+(\gamma\lambda)^{T-t-1}\delta_{T-1},
# $$
# where $\delta_{t}=r_{t+1}+\gamma V(s_{t+1})-V(s_t)$.

# %% [markdown]
# ### Mini-Batch Updates and Multiple Epochs

# %% [markdown]
# PPO collects several trajectories as a batch, then performs multiple epochs of training over minibatches.

# %% [markdown]
# ## Implementation

# %% [markdown]
# See Puffer Lab.
